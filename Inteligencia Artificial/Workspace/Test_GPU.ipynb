# %% [markdown]
# # Prueba de ambiente
#
# $$ y = x + 3 $$

# %%
print("GPU Details:")
# !nvidia-smi

print("\nCPU Details:")
# !lscpu
# Out:
# GPU Details:
#
# CPU Details:
# "nvidia-smi" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# "lscpu" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
print("Hello World")
# Out:
# Hello World
